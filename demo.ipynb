# %%
import sys
from pathlib import Path
from google.colab import drive
drive.mount("/content/gdrive/")

prefix = "/content/gdrive/Shared drives/"
customized_path_to_your_homework = "CV Project/"
sys_path = prefix + customized_path_to_your_homework
sys.path.append(sys_path)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd "/content/gdrive/Shareddrives/CV Project/Remote_sensing_image_change_detection"
# Out:
# /content/gdrive/Shareddrives/CV Project/Remote_sensing_image_change_detection

# %%
# !pip install segmentation-models-pytorch@git+https://github.com/ragavsachdeva/segmentation_models.pytorch.git@0092ee4d6f851d89a4a401bb2dfa6187660b8dd3
# !pip install kornia@git+https://github.com/kornia/kornia@77589a58be6c603b7afd755d261783bd0c152a97
# !pip install Cython matplotlib ninja opencv-python scikit-image wandb loguru yacs easydict shapely pre-commit pycocotools h5py einops

# %%
# !pip install pytorch-lightning==1.6.0

# %%
# !python demo.py --load_weights_from checkpoints/res18_512_exp-epoch=18-val_loss=0.68.ckpt --config_file configs/second_dataset.yaml --decoder_attention scse --file_path sample_images/2
# Out:
# lr_scheduler_type None
# unet_decoder_channels (256, 256, 128, 128, 64)
# Predictions saved to sample_images/2

# %%
# !python demo.py --load_weights_from checkpoints/res18_256_coam_exp_exp-epoch=7-val_loss=0.84.ckpt --config_file second_dataset.yaml --decoder_attention scse --file_path sample_images/2
# Out:
# lr_scheduler_type None
# unet_decoder_channels (256, 256, 128, 128, 64)
# 2022-12-01 01:18:37.656 | INFO     | models.segmentation_with_coam:safely_load_state_dict:105 - Dropping parameter coattention_modules.0.attention_layer.reference_dimensionality_reduction.weight
# 2022-12-01 01:18:37.656 | INFO     | models.segmentation_with_coam:safely_load_state_dict:105 - Dropping parameter coattention_modules.0.attention_layer.reference_dimensionality_reduction.bias
# 2022-12-01 01:18:37.656 | INFO     | models.segmentation_with_coam:safely_load_state_dict:105 - Dropping parameter coattention_modules.0.attention_layer.query_dimensionality_reduction.weight
# 2022-12-01 01:18:37.657 | INFO     | models.segmentation_with_coam:safely_load_state_dict:105 - Dropping parameter coattention_modules.0.attention_layer.query_dimensionality_reduction.bias
# ...
